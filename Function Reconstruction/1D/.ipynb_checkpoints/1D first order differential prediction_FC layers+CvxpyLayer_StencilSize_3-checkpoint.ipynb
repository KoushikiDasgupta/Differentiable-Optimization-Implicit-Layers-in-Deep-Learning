# %% [markdown]
# # Generating function from equn 21 in StencilNet paper

# %%
import math
import numpy as np
import torch
import matplotlib.pyplot as plt 
from tqdm import tqdm
import time
import cvxpy as cp
from cvxpylayers.torch import CvxpyLayer
import numpy.random as npr

torch.set_default_tensor_type(torch.DoubleTensor)

# %%
t = 0
N = 20
L = 2*math.pi
x = torch.linspace(0,10,200)
f = torch.tensor(0.0)
del_x = x[4]-x[3]
print("Delta x = ",del_x)

np.random.seed(0)
for i in range(1,N+1):
    A = np.random.uniform(low = -0.1, high = 0.1)
    w = np.random.uniform(low = -0.4, high = 0.4)
    phi = np.random.uniform(low = 0.0, high = 2*math.pi)
    l = np.random.choice([2,3,4,5])
    f = f + A*torch.sin(w*t + (2*math.pi*l*x)/L +phi)
    

plt.plot(x,f,label = 'Original function')
plt.xlabel('x')
plt.ylabel('f(x,0)')
plt.legend()

N = f.size(0)
testPct = 0.5    #train-test split
nTrain = int(N*(1.-testPct))

train_data = f[:nTrain]
test_data = f[nTrain:]
# Out:
# Delta x =  tensor(0.0503)

# %%
def preprocess(data):
    inputs = torch.DoubleTensor(data.size(0)-2,3)
    outputs = torch.DoubleTensor(data.size(0)-2,1)
    inputs = inputs.cuda()
    outputs = outputs.cuda()
    inputs = torch.autograd.Variable(inputs, requires_grad=True)
    outputs = torch.autograd.Variable(outputs, requires_grad=True)
    for i in range(0, data.size(0)-2):
        inputs.data[i] = torch.DoubleTensor([data[i],data[i+1],data[i+2]])
        outputs.data[i] = (data[i+2]-data[i])/(2*del_x)
        
    return inputs,outputs

train_inputs,train_outputs = preprocess(train_data)
test_inputs,test_outputs = preprocess(test_data)
plt.plot(x,f,label = 'Original function')
plt.plot(x[1:99],train_outputs.to('cpu').detach().numpy(),label = 'Target 1st order derivative (train data) with 2nd order error')
plt.plot(x[-99:-1],test_outputs.to('cpu').detach().numpy(),label = 'Target 1st order derivative (test data) with 2nd order error')
plt.legend()

# %%
class Reconstruct(torch.nn.Module):
    def __init__(self,seed = 0):
        super().__init__()
        torch.manual_seed(seed)
        self.fc1=torch.nn.Linear(3,64)
        self.fc2=torch.nn.Linear(64,3)
        self.D = torch.DoubleTensor([[1,1,1],[del_x,0,((-1)*del_x)]]).to("cuda")
        self.beta = torch.DoubleTensor([0,-1]).to("cuda")
        z = cp.Variable(3)
        D = cp.Parameter((2,3))
        beta = cp.Parameter(2)
        x = cp.Parameter(3)
        objective = (cp.sum_squares(D @ z - beta))     #L2 norm square used
        constraints = [z == x]
        problem = cp.Problem(cp.Minimize(objective),constraints)
        self.layer = CvxpyLayer(problem, parameters = [D,beta,x],
                      variables = [z])
        
    def forward(self,x):
        x = self.fc1(x)
        x = torch.nn.functional.elu(self.fc2(x))
        # when x is batched, repeat D and beta 
        if x.ndim == 2:
            batch_size = x.shape[0]
            return self.layer(self.D.repeat(batch_size, 1, 1), self.beta.repeat(batch_size, 1), x)[0]
        else:
            return self.layer(self.D, self.beta, x)[0]

# %%
def train(epoch,model,optimizer,train_inputs,train_outputs):
        
    optimizer.zero_grad()
    pred = model(train_inputs)
    loss = torch.nn.MSELoss()((pred*train_inputs).sum(1), train_outputs.flatten())
    loss.backward()
    optimizer.step()
    print('Epoch: {} \tLoss: {:.4f}'.format(epoch, loss))
    
    return loss.item()
    
def test(epoch,model,optimizer,test_inputs,test_outputs):
        
    pred = model(test_inputs)
    loss = torch.nn.MSELoss()((pred*test_inputs).sum(1), test_outputs.flatten())
        
    print('TEST SET RESULTS')
    print('Average loss: {:.4f}'.format(loss))
    
    return loss.item()

# %%
seed = 1

np.random.seed(seed)
torch.manual_seed(seed)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

model = Reconstruct(seed = seed)
if torch.cuda.is_available():
    model = model.cuda()
for param in model.parameters():
    print(param)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Out:
# Parameter containing:
# tensor([[-5.0685e-01, -3.1806e-01, -3.0686e-01],
#         [-3.7285e-01,  6.4742e-02, -4.5098e-01],
#         [-4.5134e-02,  2.4060e-01,  9.2118e-02],
#         [-3.8483e-03,  1.1980e-02, -1.9683e-01],
#         [ 2.5196e-01, -1.3336e-01, -4.7366e-01],
#         [-4.4172e-01,  1.6193e-01, -3.5014e-01],
#         [ 1.4373e-02,  2.4461e-01,  4.9060e-01],
#         [ 5.7700e-01,  4.5349e-01,  4.3500e-01],
#         [ 3.9834e-01, -3.9901e-01, -3.8043e-01],
#         [ 5.5910e-01,  3.6108e-01, -7.4075e-02],
#         [-9.8933e-02, -8.2668e-02,  2.9764e-01],
#         [ 4.8788e-01,  5.3616e-01, -3.7410e-01],
#         [ 5.2411e-01, -2.1549e-01, -5.2657e-02],
#         [-2.3608e-01, -3.6084e-01, -2.9646e-01],
#         [-1.7402e-01, -6.4580e-02, -1.0753e-01],
#         [-2.4718e-01,  3.5056e-01, -2.0581e-01],
#         [-1.5715e-01, -2.3266e-01,  1.8883e-01],
#         [-2.8271e-01, -9.8875e-02,  3.9208e-01],
#         [ 2.7924e-01, -2.4654e-01,  3.3816e-01],
#         [ 1.3432e-04,  4.5927e-01, -4.5596e-01],
#         [ 9.3431e-02,  5.6195e-01, -4.2548e-01],
#         [-3.0122e-01, -2.2553e-01,  1.8296e-02],
#         [-5.6071e-02, -8.2069e-03,  3.4717e-02],
#         [-2.7168e-01, -3.8438e-01,  5.5647e-02],
#         [-3.0259e-01,  4.3143e-02, -6.6792e-02],
#         [ 1.6788e-01,  4.3381e-02, -3.1814e-01],
#         [ 1.8843e-01,  3.9708e-01, -5.6479e-01],
#         [-2.5325e-01,  4.9665e-01,  5.0573e-02],
#         [ 3.6064e-01,  3.1751e-01,  2.6646e-01],
#         [ 5.6860e-01,  2.6349e-01, -3.0850e-01],
#         [ 5.7706e-01,  6.2359e-02, -9.2320e-02],
#         [ 4.8401e-02,  4.2051e-01, -7.9389e-02],
#         [-4.3734e-01,  4.5679e-01,  4.3697e-01],
#         [ 4.7665e-01,  5.4128e-01, -9.8148e-02],
#         [-1.0460e-01,  2.1763e-01,  2.0782e-01],
#         [ 1.6341e-01, -1.1327e-01, -1.4484e-02],
#         [ 5.2757e-01,  1.9861e-02,  5.2350e-01],
#         [ 4.0878e-01,  5.2598e-01, -4.8082e-01],
#         [-3.8295e-01, -3.5989e-01,  5.0627e-01],
#         [-1.6829e-01, -3.4329e-01,  8.0031e-03],
#         [ 2.4770e-01,  2.0796e-01,  5.4466e-01],
#         [-2.9991e-01, -1.8794e-01,  3.0049e-02],
#         [-3.7019e-01, -2.3937e-02, -2.2291e-01],
#           0.0906, -0.0055,  0.1143, -0.0827, -0.0216,  0.0519, -0.1073, -0.0034,
#           0.1021,  0.0940,  0.0949, -0.0966, -0.0579,  0.0665,  0.0085, -0.0367,
#          -0.0949, -0.0359, -0.0040,  0.0489, -0.0027, -0.1088, -0.0604,  0.0451,
#          -0.1037,  0.0260, -0.1126, -0.0430, -0.1200, -0.1074, -0.1221,  0.0250],
#         [-0.0358,  0.1076, -0.0367,  0.0964,  0.0229, -0.0147, -0.1014,  0.0104,
#           0.1087,  0.0093, -0.0376, -0.0787, -0.0447,  0.0525,  0.0794,  0.0923,
#           0.1054,  0.0030, -0.0756,  0.0813, -0.0442,  0.0201, -0.0014,  0.1159,
#           0.0897,  0.0778, -0.0574,  0.1238, -0.0078, -0.1131, -0.0748, -0.0385,
#          -0.0490, -0.0954,  0.0181, -0.1090,  0.0576,  0.0091,  0.0113,  0.0382,
#          -0.0801, -0.0939,  0.1001,  0.1141,  0.0384,  0.0575,  0.0063,  0.0694,
#          -0.1019,  0.0650,  0.0946, -0.1000,  0.0743,  0.1003,  0.0987, -0.0466,
#           0.0539, -0.0685, -0.0978, -0.0798, -0.1138, -0.0592, -0.0899, -0.0045]],
#        device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([-0.0992, -0.1172, -0.0576], device='cuda:0', requires_grad=True)

# %%
test_loss = []
train_loss = []
epochs = 100
start = time.time()
for epoch in tqdm(range(epochs)):
    trainloss = train(epoch,model,optimizer,train_inputs,train_outputs)
    testloss = test(epoch,model,optimizer,test_inputs,test_outputs)
    test_loss.append(testloss)
    train_loss.append(trainloss)

print ("Training time : ",time.time()-start)
# Out:
#   0%|                                                                                          | 0/100 [00:00<?, ?it/s]
# Epoch: 0 	Loss: 0.3055
#   1%|▊                                                                                 | 1/100 [00:01<02:34,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.3516
# Epoch: 1 	Loss: 0.3042
#   2%|█▋                                                                                | 2/100 [00:03<02:33,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.3501
# Epoch: 2 	Loss: 0.3028
#   3%|██▍                                                                               | 3/100 [00:04<02:31,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.3486
# Epoch: 3 	Loss: 0.3015
#   4%|███▎                                                                              | 4/100 [00:06<02:29,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.3471
# Epoch: 4 	Loss: 0.3002
#   5%|████                                                                              | 5/100 [00:07<02:28,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.3456
# Epoch: 5 	Loss: 0.2988
#   6%|████▉                                                                             | 6/100 [00:09<02:27,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.3441
# Epoch: 6 	Loss: 0.2975
#   7%|█████▋                                                                            | 7/100 [00:10<02:25,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.3426
# Epoch: 7 	Loss: 0.2962
#   8%|██████▌                                                                           | 8/100 [00:12<02:23,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.3411
# Epoch: 8 	Loss: 0.2949
#   9%|███████▍                                                                          | 9/100 [00:14<02:22,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.3396
# Epoch: 9 	Loss: 0.2936
#  10%|████████                                                                         | 10/100 [00:15<02:20,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.3382
# Epoch: 10 	Loss: 0.2923
#  11%|████████▉                                                                        | 11/100 [00:17<02:20,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.3368
# Epoch: 11 	Loss: 0.2911
#  12%|█████████▋                                                                       | 12/100 [00:18<02:18,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.3353
# Epoch: 12 	Loss: 0.2898
#  13%|██████████▌                                                                      | 13/100 [00:20<02:16,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.3340
# Epoch: 13 	Loss: 0.2886
#  14%|███████████▎                                                                     | 14/100 [00:21<02:14,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.3326
# Epoch: 14 	Loss: 0.2874
#  15%|████████████▏                                                                    | 15/100 [00:23<02:12,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.3312
# Epoch: 15 	Loss: 0.2862
#  16%|████████████▉                                                                    | 16/100 [00:25<02:11,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.3299
# Epoch: 16 	Loss: 0.2850
#  17%|█████████████▊                                                                   | 17/100 [00:26<02:09,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.3285
# Epoch: 17 	Loss: 0.2839
#  18%|██████████████▌                                                                  | 18/100 [00:28<02:07,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.3272
# Epoch: 18 	Loss: 0.2827
#  19%|███████████████▍                                                                 | 19/100 [00:29<02:06,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.3259
# Epoch: 19 	Loss: 0.2816
#  20%|████████████████▏                                                                | 20/100 [00:31<02:05,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.3247
# Epoch: 20 	Loss: 0.2805
#  21%|█████████████████                                                                | 21/100 [00:32<02:03,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.3234
# Epoch: 21 	Loss: 0.2794
#  22%|█████████████████▊                                                               | 22/100 [00:34<02:01,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.3222
# Epoch: 22 	Loss: 0.2783
#  23%|██████████████████▋                                                              | 23/100 [00:35<02:00,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.3209
# Epoch: 23 	Loss: 0.2772
#  24%|███████████████████▍                                                             | 24/100 [00:37<01:58,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.3197
# Epoch: 24 	Loss: 0.2762
#  25%|████████████████████▎                                                            | 25/100 [00:39<01:57,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.3185
# Epoch: 25 	Loss: 0.2751
#  26%|█████████████████████                                                            | 26/100 [00:40<01:55,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.3173
# Epoch: 26 	Loss: 0.2741
#  27%|█████████████████████▊                                                           | 27/100 [00:42<01:53,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.3161
# Epoch: 27 	Loss: 0.2730
#  28%|██████████████████████▋                                                          | 28/100 [00:43<01:53,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.3149
# Epoch: 28 	Loss: 0.2720
#  29%|███████████████████████▍                                                         | 29/100 [00:45<01:51,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.3138
# Epoch: 29 	Loss: 0.2710
#  30%|████████████████████████▎                                                        | 30/100 [00:46<01:49,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.3126
# Epoch: 30 	Loss: 0.2700
#  31%|█████████████████████████                                                        | 31/100 [00:48<01:47,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.3115
# Epoch: 31 	Loss: 0.2690
#  32%|█████████████████████████▉                                                       | 32/100 [00:50<01:46,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.3103
# Epoch: 32 	Loss: 0.2680
#  33%|██████████████████████████▋                                                      | 33/100 [00:51<01:45,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.3092
# Epoch: 33 	Loss: 0.2671
#  34%|███████████████████████████▌                                                     | 34/100 [00:53<01:43,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.3081
# Epoch: 34 	Loss: 0.2661
#  35%|████████████████████████████▎                                                    | 35/100 [00:54<01:41,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.3070
# Epoch: 35 	Loss: 0.2652
#  36%|█████████████████████████████▏                                                   | 36/100 [00:56<01:40,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.3059
# Epoch: 36 	Loss: 0.2642
#  37%|█████████████████████████████▉                                                   | 37/100 [00:57<01:38,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.3048
# Epoch: 37 	Loss: 0.2633
#  38%|██████████████████████████████▊                                                  | 38/100 [00:59<01:37,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.3037
# Epoch: 38 	Loss: 0.2624
#  39%|███████████████████████████████▌                                                 | 39/100 [01:01<01:35,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.3027
# Epoch: 39 	Loss: 0.2614
#  40%|████████████████████████████████▍                                                | 40/100 [01:02<01:33,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.3016
# Epoch: 40 	Loss: 0.2605
#  41%|█████████████████████████████████▏                                               | 41/100 [01:04<01:32,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.3006
# Epoch: 41 	Loss: 0.2596
#  42%|██████████████████████████████████                                               | 42/100 [01:05<01:30,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.2995
# Epoch: 42 	Loss: 0.2587
#  43%|██████████████████████████████████▊                                              | 43/100 [01:07<01:29,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.2985
# Epoch: 43 	Loss: 0.2578
#  44%|███████████████████████████████████▋                                             | 44/100 [01:08<01:27,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.
  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.2611
# Epoch: 88 	Loss: 0.2272
#  89%|████████████████████████████████████████████████████████████████████████         | 89/100 [02:19<00:17,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.2606
# Epoch: 89 	Loss: 0.2268
#  90%|████████████████████████████████████████████████████████████████████████▉        | 90/100 [02:21<00:15,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.2601
# Epoch: 90 	Loss: 0.2263
#  91%|█████████████████████████████████████████████████████████████████████████▋       | 91/100 [02:23<00:14,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.2596
# Epoch: 91 	Loss: 0.2259
#  92%|██████████████████████████████████████████████████████████████████████████▌      | 92/100 [02:24<00:12,  1.56s/it]
# TEST SET RESULTS
# Average loss: 0.2591
# Epoch: 92 	Loss: 0.2256
#  93%|███████████████████████████████████████████████████████████████████████████▎     | 93/100 [02:26<00:11,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.2586
# Epoch: 93 	Loss: 0.2252
#  94%|████████████████████████████████████████████████████████████████████████████▏    | 94/100 [02:27<00:09,  1.58s/it]
# TEST SET RESULTS
# Average loss: 0.2582
# Epoch: 94 	Loss: 0.2248
#  95%|████████████████████████████████████████████████████████████████████████████▉    | 95/100 [02:29<00:07,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.2577
# Epoch: 95 	Loss: 0.2245
#  96%|█████████████████████████████████████████████████████████████████████████████▊   | 96/100 [02:30<00:06,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.2573
# Epoch: 96 	Loss: 0.2241
#  97%|██████████████████████████████████████████████████████████████████████████████▌  | 97/100 [02:32<00:04,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.2569
# Epoch: 97 	Loss: 0.2238
#  98%|███████████████████████████████████████████████████████████████████████████████▍ | 98/100 [02:34<00:03,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.2565
# Epoch: 98 	Loss: 0.2235
#  99%|████████████████████████████████████████████████████████████████████████████████▏| 99/100 [02:35<00:01,  1.58s/it]
# TEST SET RESULTS
# Average loss: 0.2561
# Epoch: 99 	Loss: 0.2232
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [02:37<00:00,  1.57s/it]
# TEST SET RESULTS
# Average loss: 0.2557
# Training time :  157.239266872406

# %%
plt.plot(torch.DoubleTensor(test_loss),label = "Test Loss")
plt.plot(torch.DoubleTensor(train_loss),label = "Train Loss")
plt.legend(loc = "upper right")
plt.xlabel("Epochs")
plt.ylabel("MSE Loss")
plt.title("Loss trajectories for 2 FC layer with elu activation + CvxpyLayer")
print("Training time is 155.3 s")
print("Test loss after 100 epochs:",test_loss[-1])
print("Training loss after 100 epochs:",train_loss[-1])
# Out:
# Training time is 155.3 s
# Test loss after 100 epochs: 0.25569971128221614
# Training loss after 100 epochs: 0.22315256034531758

# %%
pred = model(test_inputs)
pred = pred.cpu().detach().numpy()
#test_inputs_noisy = test_inputs_noisy.to('cpu').detach().numpy()
test_inputs = test_inputs.to('cpu').detach().numpy()
test_outputs = test_outputs.to('cpu').detach().numpy()
#test_outputs_noisy = test_outputs_noisy.to('cpu').detach().numpy()
plt.plot(x[-99:-1],(pred*test_inputs).sum(1),label = 'Predicted 1st order derivative')
plt.plot(x[-99:-1],test_outputs.flatten(),label = 'Target 1st order derivative with 2nd order error')
plt.plot(x[-99:-1],f[-99:-1],label = 'Original function')
#plt.plot(x[-99:-1],test_outputs_noisy.flatten(),label = 'Corrupted function with 0.05 noise')
plt.legend()

# %%
plt.plot(x[-99:-1],(pred*test_inputs).sum(1),label = 'Predicted function',color = 'red')
#plt.plot(x[-99:-1],test_outputs.flatten(),label = 'Original function given',color = 'red')
plt.plot(x,f,label = 'Full original function',linestyle = 'dashed')
plt.legend()

# %%
plt.plot(pred[:,0],pred[:,1],label = 'Predicted coefficients')
plt.legend()
plt.xlabel('$\epsilon_{-1}$')
plt.ylabel('$\epsilon_{+1}$')
plt.title("Visualising predicted coefficients for 2 FC layers with moment constraints with noise")
# Out:
# Text(0.5, 1.0, 'Visualising predicted coefficients for 2 FC layers with moment constraints with noise')

# %%
plt.plot(pred[:,0]+pred[:,1]+pred[:,2])
plt.yticks([-1,0,1])
plt.title("Sum of predicted coefficients for 2 FC layers with moment constraints with noise")
# Out:
# Text(0.5, 1.0, 'Sum of predicted coefficients for 2 FC layers with moment constraints with noise')

# %%
f = open("Predicted_coefficients_test_set_noisy.txt",'w')
for i in pred:
    f.write(str(i) + "\n")
f.close()
