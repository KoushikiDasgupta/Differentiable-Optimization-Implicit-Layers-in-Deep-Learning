# %% [markdown]
# # Generating dataset, preprocessing and forming train-test split

# %%
import math
import numpy as np
import torch
import matplotlib.pyplot as plt 
from tqdm import tqdm
import time
import numpy.random as npr

torch.set_default_tensor_type(torch.DoubleTensor)

t = 0
N = 20
L = 2*math.pi
x = torch.linspace(0,10,200)
f = torch.tensor(0.0)
del_x = x[4]-x[3]

np.random.seed(0)
for i in range(1,N+1):
    A = np.random.uniform(low = -0.1, high = 0.1)
    w = np.random.uniform(low = -0.4, high = 0.4)
    phi = np.random.uniform(low = 0.0, high = 2*math.pi)
    l = np.random.choice([2,3,4,5])
    f = f + A*torch.sin(w*t + (2*math.pi*l*x)/L +phi)

plt.plot(x,f,label = 'Original function')
plt.xlabel('x')
plt.ylabel('f(x,0)')
plt.legend()

N = f.size(0)
testPct = 0.8     #train-test split
nTrain = int(N*(1.-testPct))

train_data = f[:nTrain]
test_data = f[nTrain:]

def preprocess(data):
    inputs = torch.DoubleTensor(data.size(0)-4,4)
    outputs = torch.DoubleTensor(data.size(0)-4,1)
    inputs = inputs.cuda()
    outputs = outputs.cuda()
    inputs = torch.autograd.Variable(inputs, requires_grad=True)
    outputs = torch.autograd.Variable(outputs, requires_grad=True)
    k = 0
    for i in range(2, data.size(0)-2):
        inputs.data[k] = torch.DoubleTensor([data[i-2],data[i-1],data[i+1],data[i+2]])
        outputs.data[k] = data[i]
        k = k+1
        
    return inputs,outputs

train_inputs,train_outputs = preprocess(train_data)
test_inputs,test_outputs = preprocess(test_data)

# %% [markdown]
# # Model Building and Training

# %%
class Reconstruct(torch.nn.Module):
    def __init__(self,seed = 0):
        super().__init__()
        torch.manual_seed(seed)
        self.fc1=torch.nn.Linear(4,16)
        self.fc2=torch.nn.Linear(16,4)
        
    def forward(self,x):
        x = self.fc1(x)
        x = torch.nn.functional.elu(self.fc2(x))
        return x
    
def train(epoch,model,optimizer,train_inputs,train_outputs):
        
    optimizer.zero_grad()
    pred = model(train_inputs)
    loss = torch.nn.MSELoss()((pred*train_inputs).sum(1), train_outputs.flatten())
    loss.backward()
    optimizer.step()
    print('Epoch: {} \tLoss: {:.4f}'.format(epoch, loss))
    
    return loss.item()
    
def test(epoch,model,optimizer,test_inputs,test_outputs):
        
    pred = model(test_inputs)
    loss = torch.nn.MSELoss()((pred*test_inputs).sum(1), test_outputs.flatten())
        
    print('TEST SET RESULTS')
    print('Average loss: {:.4f}'.format(loss))
    
    return loss.item()

seed = 1

np.random.seed(seed)
torch.manual_seed(seed)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

model = Reconstruct(seed = seed)
if torch.cuda.is_available():
    model = model.cuda()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

test_loss = []
train_loss = []
epochs = 100
start = time.time()
for epoch in tqdm(range(epochs)):
    trainloss = train(epoch,model,optimizer,train_inputs,train_outputs)
    testloss = test(epoch,model,optimizer,test_inputs,test_outputs)
    test_loss.append(testloss)
    train_loss.append(trainloss)

print ("Training time : ",time.time()-start)
print("Test loss after 100 epochs:",test_loss[-1])
print("Training loss after 100 epochs:",train_loss[-1])
# Out:
#  26%|█████████████████████                                                            | 26/100 [00:01<00:02, 32.08it/s]
# Epoch: 0 	Loss: 0.0652
# TEST SET RESULTS
# Average loss: 0.0340
# Epoch: 1 	Loss: 0.0639
# TEST SET RESULTS
# Average loss: 0.0334
# Epoch: 2 	Loss: 0.0627
# TEST SET RESULTS
# Average loss: 0.0328
# Epoch: 3 	Loss: 0.0614
# TEST SET RESULTS
# Average loss: 0.0322
# Epoch: 4 	Loss: 0.0601
# TEST SET RESULTS
# Average loss: 0.0316
# Epoch: 5 	Loss: 0.0588
# TEST SET RESULTS
# Average loss: 0.0311
# Epoch: 6 	Loss: 0.0575
# TEST SET RESULTS
# Average loss: 0.0305
# Epoch: 7 	Loss: 0.0563
# TEST SET RESULTS
# Average loss: 0.0299
# Epoch: 8 	Loss: 0.0550
# TEST SET RESULTS
# Average loss: 0.0293
# Epoch: 9 	Loss: 0.0537
# TEST SET RESULTS
# Average loss: 0.0287
# Epoch: 10 	Loss: 0.0525
# TEST SET RESULTS
# Average loss: 0.0282
# Epoch: 11 	Loss: 0.0513
# TEST SET RESULTS
# Average loss: 0.0276
# Epoch: 12 	Loss: 0.0500
# TEST SET RESULTS
# Average loss: 0.0270
# Epoch: 13 	Loss: 0.0488
# TEST SET RESULTS
# Average loss: 0.0264
# Epoch: 14 	Loss: 0.0476
# TEST SET RESULTS
# Average loss: 0.0259
# Epoch: 15 	Loss: 0.0463
# TEST SET RESULTS
# Average loss: 0.0253
# Epoch: 16 	Loss: 0.0451
# TEST SET RESULTS
# Average loss: 0.0248
# Epoch: 17 	Loss: 0.0439
# TEST SET RESULTS
# Average loss: 0.0242
# Epoch: 18 	Loss: 0.0428
# TEST SET RESULTS
# Average loss: 0.0237
# Epoch: 19 	Loss: 0.0416
# TEST SET RESULTS
# Average loss: 0.0231
# Epoch: 20 	Loss: 0.0404
# TEST SET RESULTS
# Average loss: 0.0226
# Epoch: 21 	Loss: 0.0393
# TEST SET RESULTS
# Average loss: 0.0221
# Epoch: 22 	Loss: 0.0381
# TEST SET RESULTS
# Average loss: 0.0215
# Epoch: 23 	Loss: 0.0370
# TEST SET RESULTS
# Average loss: 0.0210
# Epoch: 24 	Loss: 0.0359
# TEST SET RESULTS
# Average loss: 0.0205
# Epoch: 25 	Loss: 0.0348
# TEST SET RESULTS
# Average loss: 0.0200
# Epoch: 26 	Loss: 0.0337
# TEST SET RESULTS
# Average loss: 0.0195
# Epoch: 27 	Loss: 0.0326
# TEST SET RESULTS
# Average loss: 0.0190
# Epoch: 28 	Loss: 0.0315
# TEST SET RESULTS
# Average loss: 0.0185
# Epoch: 29 	Loss: 0.0305
# TEST SET RESULTS
# Average loss: 0.0180
# Epoch: 30 	Loss: 0.0295
# TEST SET RESULTS
# Average loss: 0.0175
# Epoch: 31 	Loss: 0.0285
# TEST SET RESULTS
# Average loss: 0.0170
# Epoch: 32 	Loss: 0.0275
# TEST SET RESULTS
# Average loss: 0.0165
# Epoch: 33 	Loss: 0.0265
# TEST SET RESULTS
# Average loss: 0.0161
# Epoch: 34 	Loss: 0.0255
# TEST SET RESULTS
# Average loss: 0.0156
# Epoch: 35 	Loss: 0.0246
# TEST SET RESULTS
# Average loss: 0.0152
# Epoch: 36 	Loss: 0.0237
# TEST SET RESULTS
# Average loss: 0.0147
# Epoch: 37 	Loss: 0.0228
# TEST SET RESULTS
# Average loss: 0.0143
# Epoch: 38 	Loss: 0.0219
# TEST SET RESULTS
# Average loss: 0.0139
# Epoch: 39 	Loss: 0.0211
# TEST SET RESULTS
#  74%|███████████████████████████████████████████████████████████▉                     | 74/100 [00:01<00:00, 92.50it/s]
# Average loss: 0.0135
# Epoch: 40 	Loss: 0.0203
# TEST SET RESULTS
# Average loss: 0.0130
# Epoch: 41 	Loss: 0.0195
# TEST SET RESULTS
# Average loss: 0.0126
# Epoch: 42 	Loss: 0.0187
# TEST SET RESULTS
# Average loss: 0.0123
# Epoch: 43 	Loss: 0.0179
# TEST SET RESULTS
# Average loss: 0.0119
# Epoch: 44 	Loss: 0.0172
# TEST SET RESULTS
# Average loss: 0.0115
# Epoch: 45 	Loss: 0.0165
# TEST SET RESULTS
# Average loss: 0.0111
# Epoch: 46 	Loss: 0.0158
# TEST SET RESULTS
# Average loss: 0.0108
# Epoch: 47 	Loss: 0.0152
# TEST SET RESULTS
# Average loss: 0.0104
# Epoch: 48 	Loss: 0.0145
# TEST SET RESULTS
# Average loss: 0.0101
# Epoch: 49 	Loss: 0.0139
# TEST SET RESULTS
# Average loss: 0.0098
# Epoch: 50 	Loss: 0.0133
# TEST SET RESULTS
# Average loss: 0.0095
# Epoch: 51 	Loss: 0.0128
# TEST SET RESULTS
# Average loss: 0.0091
# Epoch: 52 	Loss: 0.0122
# TEST SET RESULTS
# Average loss: 0.0088
# Epoch: 53 	Loss: 0.0117
# TEST SET RESULTS
# Average loss: 0.0085
# Epoch: 54 	Loss: 0.0112
# TEST SET RESULTS
# Average loss: 0.0083
# Epoch: 55 	Loss: 0.0107
# TEST SET RESULTS
# Average loss: 0.0080
# Epoch: 56 	Loss: 0.0103
# TEST SET RESULTS
# Average loss: 0.0077
# Epoch: 57 	Loss: 0.0099
# TEST SET RESULTS
# Average loss: 0.0074
# Epoch: 58 	Loss: 0.0094
# TEST SET RESULTS
# Average loss: 0.0072
# Epoch: 59 	Loss: 0.0090
# TEST SET RESULTS
# Average loss: 0.0069
# Epoch: 60 	Loss: 0.0087
# TEST SET RESULTS
# Average loss: 0.0067
# Epoch: 61 	Loss: 0.0083
# TEST SET RESULTS
# Average loss: 0.0065
# Epoch: 62 	Loss: 0.0080
# TEST SET RESULTS
# Average loss: 0.0062
# Epoch: 63 	Loss: 0.0076
# TEST SET RESULTS
# Average loss: 0.0060
# Epoch: 64 	Loss: 0.0073
# TEST SET RESULTS
# Average loss: 0.0058
# Epoch: 65 	Loss: 0.0070
# TEST SET RESULTS
# Average loss: 0.0056
# Epoch: 66 	Loss: 0.0068
# TEST SET RESULTS
# Average loss: 0.0054
# Epoch: 67 	Loss: 0.0065
# TEST SET RESULTS
# Average loss: 0.0052
# Epoch: 68 	Loss: 0.0062
# TEST SET RESULTS
# Average loss: 0.0050
# Epoch: 69 	Loss: 0.0060
# TEST SET RESULTS
# Average loss: 0.0048
# Epoch: 70 	Loss: 0.0057
# TEST SET RESULTS
# Average loss: 0.0046
# Epoch: 71 	Loss: 0.0055
# TEST SET RESULTS
# Average loss: 0.0044
# Epoch: 72 	Loss: 0.0053
# TEST SET RESULTS
# Average loss: 0.0043
# Epoch: 73 	Loss: 0.0051
# TEST SET RESULTS
# Average loss: 0.0041
# Epoch: 74 	Loss: 0.0049
# TEST SET RESULTS
# Average loss: 0.0039
# Epoch: 75 	Loss: 0.0047
# TEST SET RESULTS
# Average loss: 0.0038
# Epoch: 76 	Loss: 0.0045
# TEST SET RESULTS
# Average loss: 0.0036
# Epoch: 77 	Loss: 0.0043
# TEST SET RESULTS
# Average loss: 0.0035
# Epoch: 78 	Loss: 0.0041
# TEST SET RESULTS
# Average loss: 0.0033
# Epoch: 79 	Loss: 0.0039
# TEST SET RESULTS
# Average loss: 0.0032
# Epoch: 80 	Loss: 0.0038
# TEST SET RESULTS
# Average loss: 0.0031
# Epoch: 81 	Loss: 0.0036
# TEST SET RESULTS
# Average loss: 0.0029
# Epoch: 82 	Loss: 0.0035
# TEST SET RESULTS
# Average loss: 0.0028
# Epoch: 83 	Loss: 0.0033
# TEST SET RESULTS
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 70.17it/s]
# Average loss: 0.0027
# Epoch: 84 	Loss: 0.0032
# TEST SET RESULTS
# Average loss: 0.0026
# Epoch: 85 	Loss: 0.0030
# TEST SET RESULTS
# Average loss: 0.0024
# Epoch: 86 	Loss: 0.0029
# TEST SET RESULTS
# Average loss: 0.0023
# Epoch: 87 	Loss: 0.0028
# TEST SET RESULTS
# Average loss: 0.0022
# Epoch: 88 	Loss: 0.0027
# TEST SET RESULTS
# Average loss: 0.0021
# Epoch: 89 	Loss: 0.0025
# TEST SET RESULTS
# Average loss: 0.0020
# Epoch: 90 	Loss: 0.0024
# TEST SET RESULTS
# Average loss: 0.0019
# Epoch: 91 	Loss: 0.0023
# TEST SET RESULTS
# Average loss: 0.0018
# Epoch: 92 	Loss: 0.0022
# TEST SET RESULTS
# Average loss: 0.0018
# Epoch: 93 	Loss: 0.0021
# TEST SET RESULTS
# Average loss: 0.0017
# Epoch: 94 	Loss: 0.0020
# TEST SET RESULTS
# Average loss: 0.0016
# Epoch: 95 	Loss: 0.0019
# TEST SET RESULTS
# Average loss: 0.0015
# Epoch: 96 	Loss: 0.0018
# TEST SET RESULTS
# Average loss: 0.0014
# Epoch: 97 	Loss: 0.0017
# TEST SET RESULTS
# Average loss: 0.0014
# Epoch: 98 	Loss: 0.0017
# TEST SET RESULTS
# Average loss: 0.0013
# Epoch: 99 	Loss: 0.0016
# TEST SET RESULTS
# Average loss: 0.0012
# Training time :  1.431739330291748
# Test loss after 100 epochs: 0.0012400141297764504
# Training loss after 100 epochs: 0.0015863212386987584

# %% [markdown]
# # Plotting outputs

# %%
fig, ax = plt.subplots(4, 2)
fig.set_figwidth(18)
fig.set_figheight(22)

ax[0,0].plot(test_loss,label = "Test Loss")
ax[0,0].plot(train_loss,label = "Train Loss")
ax[0,0].legend(loc = "upper right")
ax[0,0].set_xlabel("Epochs")
ax[0,0].set_ylabel("MSE Loss")
ax[0,0].set_title("Loss trajectories for 2 FC layer with elu activation without moment constraints")

pred = model(test_inputs)
pred = pred.cpu().detach().numpy()
test_inputs = test_inputs.to('cpu').detach().numpy()
test_outputs = test_outputs.to('cpu').detach().numpy()

ax[0,1].plot(x[-159:-2],(pred*test_inputs).sum(1),label = 'Predicted function',color = 'red')
ax[0,1].plot(x,f,label = 'Full original function',linestyle = 'dashed')
ax[0,1].legend()
ax[0,1].set_title("Prediction plot with 2 FC layers without moment constraints")

ax[1,0].plot(pred[:,1],pred[:,2],label = 'Predicted coefficients')
ax[1,0].legend()
ax[1,0].set_xlabel('$\epsilon_{-1}$')
ax[1,0].set_ylabel('$\epsilon_{+1}$')
ax[1,0].set_title("Visualising predicted coefficients for 2 FC layers without moment constraints")

ax[1,1].plot(pred[:,0],pred[:,3],label = 'Predicted coefficients')
ax[1,1].legend()
ax[1,1].set_xlabel('$\epsilon_{-2}$')
ax[1,1].set_ylabel('$\epsilon_{+2}$')
ax[1,1].set_title("Visualising predicted coefficients for 2 FC layers without moment constraints")

ax[2,0].plot(x[-159:-2],(pred*test_inputs).sum(1),label = 'Predicted function')
ax[2,0].plot(x[-159:-2],test_outputs.flatten(),label = 'Original function')
ax[2,0].legend()
ax[2,0].set_title("Prediction plot with 2 FC layers without moment constraints")

ax[2,1].plot(x[-159:-2],pred[:,0]+pred[:,1]+pred[:,2]+pred[:,3])
ax[2,1].set_title("Sum of 0th order moments for 2 FC layers without moment constraints")

ax[3,0].plot(x[-159:-2],2*del_x*pred[:,0]+del_x*pred[:,1]+(-1)*del_x*pred[:,2]+(-2)*del_x*pred[:,3])
ax[3,0].set_title("Sum of 1st order moments for 2 FC layers without moment constraints")

ax[3,1].plot(x[-159:-2],4*pow(del_x,2)*pred[:,0]+pow(del_x,2)*pred[:,1]+pow(del_x,2)*pred[:,2]+4*pow(del_x,2)*pred[:,3])
ax[3,1].set_title("Sum of 2nd order moments for 2 FC layers without moment constraints")

#ax[4,0].plot(x[-159:-2],8*pow(del_x,3)*pred[:,0]+pow(del_x,3)*pred[:,1]+(-1)*pow(del_x,3)*pred[:,2]+(-8)*pow(del_x,3)*pred[:,3])
#ax[4,0].set_title("Sum of 3rd order moments for 2 FC layers with moment constraints")
# Out:
# Text(0.5, 1.0, 'Sum of 2nd order moments for 2 FC layers without moment constraints')

# %% [markdown]
# # Storing predicted coefficients in text file

# %%
f = open("Predicted_coefficients_test_set_without_Cvxpy.txt",'w')
for i in pred:
    f.write(str(i) + "\n")
f.close()
