# %% [markdown]
# # Generating dataset, preprocessing and forming train-test splits

# %%
import math
import numpy as np
import torch
import matplotlib.pyplot as plt 
from tqdm import tqdm
import time
import numpy.random as npr

torch.set_default_tensor_type(torch.DoubleTensor)

t = 0
N = 20
L = 2*math.pi
x = torch.linspace(0,10,200)
f = torch.tensor(0.0)
del_x = x[4]-x[3]

np.random.seed(0)
for i in range(1,N+1):
    A = np.random.uniform(low = -0.1, high = 0.1)
    w = np.random.uniform(low = -0.4, high = 0.4)
    phi = np.random.uniform(low = 0.0, high = 2*math.pi)
    l = np.random.choice([2,3,4,5])
    f = f + A*torch.sin(w*t + (2*math.pi*l*x)/L +phi)


plt.plot(x,f,label = 'Original function')
plt.xlabel('x')
plt.ylabel('f(x,0)')
plt.legend()

N = f.size(0)
testPct = 0.5     #train-test split
nTrain = int(N*(1.-testPct))

train_data = f[:nTrain].to("cuda")
test_data = f[nTrain:].to("cuda")

def make_patches(data):
    inputs = torch.DoubleTensor(data.size(0)-2,2)
    outputs = torch.DoubleTensor(data.size(0)-2,1)
    inputs = inputs.cuda()
    outputs = outputs.cuda()
    inputs = torch.autograd.Variable(inputs, requires_grad=True)
    outputs = torch.autograd.Variable(outputs, requires_grad=True)
    for i in range(0, data.size(0)-2):
        inputs.data[i] = torch.DoubleTensor([data[i],data[i+2]])
        outputs.data[i] = data[i+1]
        
    return inputs,outputs

# %% [markdown]
# # Model Building and Training

# %%
class Reconstruct(torch.nn.Module):
    def __init__(self,seed = 0):
        super().__init__()
        torch.manual_seed(seed)                               #input dim is (1,1,data_len)  
        self.layer1 = torch.nn.Conv1d(1,4,2,dilation = 2)     #4 filters with filter size 2 each with 2 dilation, output of this layer is (1,4,data_len-2) 
        self.layer2 = torch.nn.Linear(4,2)                    #input to this layer gets changed to (data_len-2,1,4) ;output of this layer is (data_len-2,1,2)
        
    def forward(self,x):
        x = self.layer1(x)
        x = x.view(x.size(2),1,x.size(1))
        x = torch.nn.functional.elu(self.layer2(x))
        return x
    
def train(epoch,model,optimizer,train_data,train_inputs,train_outputs):
        
    optimizer.zero_grad()
    pred = model(train_data)
    pred = pred.view(pred.size(0),pred.size(2))
    loss = torch.nn.MSELoss()((pred*train_inputs).sum(1), train_outputs.flatten())
    loss.backward()
    optimizer.step()
    print('Epoch: {} \tLoss: {:.4f}'.format(epoch, loss))
    
    return loss.item()
    
def test(epoch,model,optimizer,test_data,test_inputs,test_outputs):
     
    pred = model(test_data) 
    pred = pred.view(pred.size(0),pred.size(2))
    loss = torch.nn.MSELoss()((pred*test_inputs).sum(1), test_outputs.flatten())
    
    print('TEST SET RESULTS')
    print('Average loss: {:.4f}'.format(loss))
    
    return loss.item()

seed = 1

np.random.seed(seed)
torch.manual_seed(seed)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

model = Reconstruct(seed = seed)
if torch.cuda.is_available():
    model = model.cuda()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

train_inputs, train_outputs = make_patches(train_data)
test_inputs, test_outputs = make_patches(test_data)
train_data = train_data.view(1,1,train_data.size(0))
test_data = train_data.view(1,1,test_data.size(0))
test_loss = []
train_loss = []
epochs = 100
start = time.time()
for epoch in tqdm(range(epochs)):
    trainloss = train(epoch,model,optimizer,train_data,train_inputs,train_outputs)
    testloss = test(epoch,model,optimizer,test_data,test_inputs,test_outputs)
    test_loss.append(testloss)
    train_loss.append(trainloss)
    #if testloss <= 1e-2:
     #   break

print ("Training time : ",time.time()-start)
print("Test loss after 100 epochs:",test_loss[-1])
print("Training loss after 100 epochs:",train_loss[-1])
# Out:
#  19%|███████████████▏                                                                | 19/100 [00:00<00:00, 180.55it/s]
# Epoch: 0 	Loss: 0.0004
# TEST SET RESULTS
# Average loss: 0.0003
# Epoch: 1 	Loss: 0.0004
# TEST SET RESULTS
# Average loss: 0.0003
# Epoch: 2 	Loss: 0.0004
# TEST SET RESULTS
# Average loss: 0.0003
# Epoch: 3 	Loss: 0.0004
# TEST SET RESULTS
# Average loss: 0.0003
# Epoch: 4 	Loss: 0.0003
# TEST SET RESULTS
# Average loss: 0.0003
# Epoch: 5 	Loss: 0.0003
# TEST SET RESULTS
# Average loss: 0.0002
# Epoch: 6 	Loss: 0.0003
# TEST SET RESULTS
# Average loss: 0.0002
# Epoch: 7 	Loss: 0.0003
# TEST SET RESULTS
# Average loss: 0.0002
# Epoch: 8 	Loss: 0.0003
# TEST SET RESULTS
# Average loss: 0.0002
# Epoch: 9 	Loss: 0.0003
# TEST SET RESULTS
# Average loss: 0.0002
# Epoch: 10 	Loss: 0.0003
# TEST SET RESULTS
# Average loss: 0.0002
# Epoch: 11 	Loss: 0.0003
# TEST SET RESULTS
# Average loss: 0.0002
# Epoch: 12 	Loss: 0.0002
# TEST SET RESULTS
# Average loss: 0.0002
# Epoch: 13 	Loss: 0.0002
# TEST SET RESULTS
# Average loss: 0.0002
# Epoch: 14 	Loss: 0.0002
# TEST SET RESULTS
# Average loss: 0.0002
# Epoch: 15 	Loss: 0.0002
# TEST SET RESULTS
# Average loss: 0.0002
# Epoch: 16 	Loss: 0.0002
# TEST SET RESULTS
# Average loss: 0.0002
# Epoch: 17 	Loss: 0.0002
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 18 	Loss: 0.0002
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 19 	Loss: 0.0002
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 20 	Loss: 0.0002
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 21 	Loss: 0.0002
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 22 	Loss: 0.0002
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 23 	Loss: 0.0002
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 24 	Loss: 0.0001
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 25 	Loss: 0.0001
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 26 	Loss: 0.0001
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 27 	Loss: 0.0001
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 28 	Loss: 0.0001
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 29 	Loss: 0.0001
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 30 	Loss: 0.0001
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 31 	Loss: 0.0001
#  57%|█████████████████████████████████████████████▌                                  | 57/100 [00:00<00:00, 175.96it/s]
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 32 	Loss: 0.0001
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 33 	Loss: 0.0001
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 34 	Loss: 0.0001
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 35 	Loss: 0.0001
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 36 	Loss: 0.0001
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 37 	Loss: 0.0001
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 38 	Loss: 0.0001
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 39 	Loss: 0.0001
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 40 	Loss: 0.0001
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 41 	Loss: 0.0001
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 42 	Loss: 0.0001
# TEST SET RESULTS
# Average loss: 0.0001
# Epoch: 43 	Loss: 0.0001
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 44 	Loss: 0.0001
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 45 	Loss: 0.0001
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 46 	Loss: 0.0001
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 47 	Loss: 0.0001
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 48 	Loss: 0.0001
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 49 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 50 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 51 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 52 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 53 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 54 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 55 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 56 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 57 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 58 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 59 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 60 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 61 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 62 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
#  93%|██████████████████████████████████████████████████████████████████████████▍     | 93/100 [00:00<00:00, 171.38it/s]
# Epoch: 63 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 64 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 65 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 66 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 67 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 68 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 69 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 70 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 71 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 72 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 73 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 74 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 75 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 76 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 77 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 78 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 79 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 80 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 81 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 82 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 83 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 84 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 85 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 86 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 87 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 88 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 89 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 90 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 91 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 92 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 93 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 94 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 95 	Loss: 0.0000
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 171.74it/s]
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 96 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 97 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 98 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Epoch: 99 	Loss: 0.0000
# TEST SET RESULTS
# Average loss: 0.0000
# Training time :  0.5902554988861084
# Test loss after 100 epochs: 1.988128475470379e-05
# Training loss after 100 epochs: 1.8192039472486767e-05

# %% [markdown]
# # Plotting outputs

# %%
fig, ax = plt.subplots(3, 2)
fig.set_figwidth(18)
fig.set_figheight(16)

ax[0,0].plot(test_loss,label = "Test Loss")
ax[0,0].plot(train_loss,label = "Train Loss")
ax[0,0].legend(loc = "upper right")
#ax[0,0].set_yscale("log")
ax[0,0].set_xlabel("Epochs")
ax[0,0].set_ylabel("MSE Loss")
ax[0,0].set_title("Loss trajectories for CNN network without moment constraints")

pred = model(test_data) 
pred = pred.view(pred.size(0),pred.size(2))
pred = pred.cpu().detach().numpy()
test_inputs = test_inputs.to('cpu').detach().numpy()
test_outputs = test_outputs.to('cpu').detach().numpy()
ax[0,1].plot(x[-99:-1],(pred*test_inputs).sum(1),label = 'Predicted function')
ax[0,1].plot(x[-99:-1],test_outputs.flatten(),label = 'Original function')
ax[0,1].legend()
ax[0,1].set_title("Prediction plot with CNN network without moment constraints")

ax[1,0].plot(pred[:,0],pred[:,1],label = 'Predicted coefficients')
ax[1,0].legend()
ax[1,0].set_xlabel('$\epsilon_{-1}$')
ax[1,0].set_ylabel('$\epsilon_{+1}$')
ax[1,0].set_title("Visualising predicted coefficients for CNN network without moment constraints")

ax[1,1].plot(x[-99:-1],pred[:,0]+pred[:,1])
ax[1,1].set_title("Sum of 0th order moments for CNN network without moment constraints")

ax[2,0].plot(x[-99:-1],(pred*test_inputs).sum(1),label = 'Predicted function',color = 'red')
ax[2,0].plot(x,f,label = 'Full Original function',color = 'blue',linestyle = 'dashed')
ax[2,0].legend()
ax[2,0].set_title("Prediction plot with CNN network without moment constraints")

ax[2,1].plot(x[-99:-1],(del_x)*pred[:,0]+(-del_x)*pred[:,1])
ax[2,1].set_title("Sum of 1st order moments for CNN network without moment constraints")
# Out:
# Text(0.5, 1.0, 'Sum of 1st order moments for CNN network without moment constraints')

# %% [markdown]
# # Storing predicted coefficients in text file

# %%
f = open("Predicted_coefficients_test_set_without_Cvxpy.txt",'w')
for i in pred:
    f.write(str(i) + "\n")
f.close()
