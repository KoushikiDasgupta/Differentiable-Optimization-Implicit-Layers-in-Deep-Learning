# %% [markdown]
# # Generating dataset, preprocessing and forming train-test splits

# %%
import math
import numpy as np
import torch
import matplotlib.pyplot as plt 
from tqdm import tqdm
import time
import numpy.random as npr

torch.set_default_tensor_type(torch.DoubleTensor)

t = 0
N = 20
L = 2*math.pi
x = torch.linspace(0,10,200)
f = torch.tensor(0.0)
del_x = x[4]-x[3]

np.random.seed(0)
for i in range(1,N+1):
    A = np.random.uniform(low = -0.1, high = 0.1)
    w = np.random.uniform(low = -0.4, high = 0.4)
    phi = np.random.uniform(low = 0.0, high = 2*math.pi)
    l = np.random.choice([2,3,4,5])
    f = f + A*torch.sin(w*t + (2*math.pi*l*x)/L +phi)

N = f.size(0)
testPct = 0.5     #train-test split
nTrain = int(N*(1.-testPct))

train_data = f[:nTrain]
test_data = f[nTrain:]

def preprocess(data):
    inputs = torch.DoubleTensor(data.size(0)-2,3)
    outputs = torch.DoubleTensor(data.size(0)-2,1)
    inputs = inputs.cuda()
    outputs = outputs.cuda()
    inputs = torch.autograd.Variable(inputs, requires_grad=True)
    outputs = torch.autograd.Variable(outputs, requires_grad=True)
    for i in range(0, data.size(0)-2):
        inputs.data[i] = torch.DoubleTensor([data[i],data[i+1],data[i+2]])
        outputs.data[i] = (data[i+1]-data[i])/del_x
        
    return inputs,outputs

train_inputs,train_outputs = preprocess(train_data)
test_inputs,test_outputs = preprocess(test_data)
plt.plot(x,f,label = 'Original function')
plt.plot(x[1:99],train_outputs.to('cpu').detach().numpy(),label = 'Target 1st order derivative (train data) calculated by backward differencing')
plt.plot(x[-99:-1],test_outputs.to('cpu').detach().numpy(),label = 'Target 1st order derivative (test data) calculated by backward differencing')
plt.legend()

# %% [markdown]
# # Model Building and Training

# %%
class Reconstruct(torch.nn.Module):
    def __init__(self,seed = 0):
        super().__init__()
        torch.manual_seed(seed)
        self.fc1=torch.nn.Linear(3,300)
        self.fc2=torch.nn.Linear(300,3)
        
    def forward(self,x):
        x = self.fc1(x)
        x = self.fc2(x)
        return x
    
def train(epoch,model,optimizer,train_inputs,train_outputs):
        
    optimizer.zero_grad()
    pred = model(train_inputs)
    loss = torch.nn.MSELoss()((pred*train_inputs).sum(1), train_outputs.flatten())
    loss.backward()
    optimizer.step()
    print('Epoch: {} \tLoss: {:.4f}'.format(epoch, loss))
    
    return loss.item()
    
def test(epoch,model,optimizer,test_inputs,test_outputs):
        
    pred = model(test_inputs)
    loss = torch.nn.MSELoss()((pred*test_inputs).sum(1), test_outputs.flatten())
        
    print('TEST SET RESULTS')
    print('Average loss: {:.4f}'.format(loss))
    
    return loss.item()

seed = 1

np.random.seed(seed)
torch.manual_seed(seed)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

model = Reconstruct(seed = seed)
if torch.cuda.is_available():
    model = model.cuda()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

test_loss = []
train_loss = []
epochs = 100
start = time.time()
for epoch in tqdm(range(epochs)):
    trainloss = train(epoch,model,optimizer,train_inputs,train_outputs)
    testloss = test(epoch,model,optimizer,test_inputs,test_outputs)
    test_loss.append(testloss)
    train_loss.append(trainloss)

print ("Training time : ",time.time()-start)
print("Test loss after 100 epochs:",test_loss[-1])
print("Training loss after 100 epochs:",train_loss[-1])
# Out:
#  27%|█████████████████████▊                                                           | 27/100 [00:01<00:02, 35.72it/s]
# Epoch: 0 	Loss: 0.3272
# TEST SET RESULTS
# Average loss: 0.3597
# Epoch: 1 	Loss: 0.3187
# TEST SET RESULTS
# Average loss: 0.3505
# Epoch: 2 	Loss: 0.3108
# TEST SET RESULTS
# Average loss: 0.0279
# Epoch: 80 	Loss: 0.0249
# TEST SET RESULTS
# Average loss: 0.0264
# Epoch: 81 	Loss: 0.0235
# TEST SET RESULTS
# Average loss: 0.0249
# Epoch: 82 	Loss: 0.0222
# TEST SET RESULTS
# Average loss: 0.0235
# Epoch: 83 	Loss: 0.0209
# TEST SET RESULTS
# Average loss: 0.0221
# Epoch: 84 	Loss: 0.0197
# TEST SET RESULTS
# Average loss: 0.0208
# Epoch: 85 	Loss: 0.0186
# TEST SET RESULTS
# Average loss: 0.0196
# Epoch: 86 	Loss: 0.0175
# TEST SET RESULTS
# Average loss: 0.0184
# Epoch: 87 	Loss: 0.0164
# TEST SET RESULTS
# Average loss: 0.0172
# Epoch: 88 	Loss: 0.0154
# TEST SET RESULTS
# Average loss: 0.0162
# Epoch: 89 	Loss: 0.0144
# TEST SET RESULTS
# Average loss: 0.0151
# Epoch: 90 	Loss: 0.0135
# TEST SET RESULTS
# Average loss: 0.0142
# Epoch: 91 	Loss: 0.0127
# TEST SET RESULTS
# Average loss: 0.0132
# Epoch: 92 	Loss: 0.0118
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 76.01it/s]
# TEST SET RESULTS
# Average loss: 0.0124
# Epoch: 93 	Loss: 0.0111
# TEST SET RESULTS
# Average loss: 0.0115
# Epoch: 94 	Loss: 0.0103
# TEST SET RESULTS
# Average loss: 0.0108
# Epoch: 95 	Loss: 0.0096
# TEST SET RESULTS
# Average loss: 0.0100
# Epoch: 96 	Loss: 0.0090
# TEST SET RESULTS
# Average loss: 0.0093
# Epoch: 97 	Loss: 0.0084
# TEST SET RESULTS
# Average loss: 0.0087
# Epoch: 98 	Loss: 0.0078
# TEST SET RESULTS
# Average loss: 0.0080
# Epoch: 99 	Loss: 0.0072
# TEST SET RESULTS
# Average loss: 0.0075
# Training time :  1.3225462436676025
# Test loss after 100 epochs: 0.007461047659946025
# Training loss after 100 epochs: 0.00724695420994434

# %% [markdown]
# # Plotting outputs

# %%
fig, ax = plt.subplots(2, 2)
fig.set_figwidth(16)
fig.set_figheight(10)

ax[0,0].plot(test_loss,label = "Test Loss")
ax[0,0].plot(train_loss,label = "Train Loss")
ax[0,0].legend(loc = "upper right")
ax[0,0].set_xlabel("Epochs")
ax[0,0].set_ylabel("MSE Loss")
ax[0,0].set_title("Loss trajectories for 2 FC layer without moment constraints")

pred = model(test_inputs)
pred = pred.cpu().detach().numpy()
test_inputs = test_inputs.to('cpu').detach().numpy()
test_outputs = test_outputs.to('cpu').detach().numpy()

ax[0,1].plot(x[-99:-1],(pred*test_inputs).sum(1),label = 'Predicted 1st order derivative')
ax[0,1].plot(x[-99:-1],test_outputs.flatten(),label = 'Target 1st order derivative calculated by backward differencing')
ax[0,1].legend()
ax[0,1].set_title("Prediction plot with 2 FC layers without moment constraints")

ax[1,0].plot(x[-99:-1],pred[:,0]+pred[:,1]+pred[:,2])
ax[1,0].set_title("Sum of 0th order moments for 2 FC layers without moment constraints")

ax[1,1].plot(x[-99:-1],(del_x*pred[:,0])+(del_x*(-1)*pred[:,2]))
ax[1,1].set_title("Sum of 1st order moments for 2 FC layers without moment constraints")
# Out:
# Text(0.5, 1.0, 'Sum of 1st order moments for 2 FC layers without moment constraints')

# %% [markdown]
# # Storing predicted coefficients in text file

# %%
f = open("Predicted_coefficients_test_set_without_Cvxpy.txt",'w')
for i in pred:
    f.write(str(i) + "\n")
f.close()
